# %%
first_5_even=[2,4,6,8,10]
sum_even=sum(first_5_even)
print(f"even sum: {sum_even}")
# Out:
# even sum: 30

# %%
## Question 1: Calculate the product of first 10 natural numbers
product=1
for i in range(1,11):
    product *=i
    print(product,end=",")
# Out:
# 1,2,6,24,120,720,5040,40320,362880,3628800,

# %%
product=1
for i in range(6,19):
    product*=i
print(product)
# Out:
# 53353114214400

# %%
product=1
for i in range(6,11):
    product*=i
print(product)
# Out:
# 30240

# %%
product=1
for i in range(1,11):
    product *=i
    print(product,end=",")
# Out:
# 1,2,6,24,120,720,5040,40320,362880,3628800,

# %%
product=1
for i in range(1,11):
    product *=i
print(product)
# Out:
# 3628800

# %%
product=1
for i in range(6,14):
    product*=i
print(product)
# Out:
# 51891840

# %%
import math
product=math.prod(range(1,11))
print(product)
# Out:
# 3628800

# %%
 ##Question 2: Find the remainder when 156 is divided by 7
ds_students=156
ds_faculty=7
remaind_=int(ds_students/ds_faculty)
print(f"the remaining students : {remaind_}")
# Out:
# the remaining students : 22

# %%
total_rooms=18
total_people=175
remain_people=int(total_people/total_rooms)
print(remain_people)
# Out:
# 9

# %%
# Question 3: Calculate the square of 25
base=25
power=2
square_1=base**power
print(f"square of 25 : {square_1}")
# Out:
# square of 25 : 625

# %%
square_2=pow(base,power)
print(f"square value of 25: {square_2}")
# Out:
# square value of 25: 625

# %%
total_classes=35
total_class_rooms=2
total_strength=total_classes**total_class_rooms
print(total_strength)
# Out:
# 1225

# %%
# Question 4: Find the cube root of 125
num=125
result=round(num**(1/3))
print(result)
# Out:
# 5

# %%
num=1331
result=round(num**(1/3))
print(result)
# Out:
# 11

# %%
num=25
result=int(num**0.5)
print(result)
# Out:
# 5

# %%
num=8
result=int(num**1/3)
print(result)
# Out:
# 2

# %%
# Question 5: Calculate the sum of digits in number 12345
num=12345
sum_digit=0
for digit in str(num):
    sum_digit+=int(digit)
print(f"sum of gidits:{sum_digit}")
# Out:
# sum of gidits:15

# %%
num=98765
sum_digits=0
for digit in str(num):
    sum_digits+=int(digit)
print(sum_digits)
# Out:
# 35

# %%
nums=12345678987654321
sum_digi=0
for digi in str(nums):
    sum_digi+=int(digi)
print(sum_digi)
# Out:
# 81

# %%
num=6789
sum_digit=0
for digit in str(num):
    sum_digit+=int(digit)
print(sum_digit)
# Out:
# 30

# %%
num=48485584849
sum_digit=0
for i in str(num):
    sum_digit+=int(i)
print(sum_digit)
# Out:
# 67

# %%
nums=45783649817676387
sum_digit=0
for digit in str(nums):
    sum_digit+=int(digit)
print(sum_digit)
# Out:
# 99

# %%
num=12345
sum_digits=sum(int(d) for d in str(num))
print(sum_digits)
# Out:
# 15

# %%
# Question 6: Check if 97 is a prime number
num=97
if num % 2 !=0:
    print("True")
else:
    print("False")
# Out:
# True

# %%
num=97
is_prime=True

for i in range(2,num):
    if num % i == 0:
        is_prime=False
        break
print("prime" if is_prime else "not prime")
# Out:
# prime

# %%
num=51
is_prime=True
for i in range(2,num):
    if num % i ==0:
        is_prime=False
        break
print("prime" if is_prime else "not prime")
# Out:
# not prime

# %%
num=163643
is_prime=True
for i in range(2,num):
    if num % i ==0:
        is_prime=False
        break
print("prime" if is_prime else "not prime")
# Out:
# prime

# %%
num=98765
is_prime=True
for i in range(2,num):
    if num % i ==0:
        is_prime=False
        break
print(is_prime)
# Out:
# False

# %%
num=5696563487569384758857
prime=True
for i in range(2,num):
    if num % i ==0:
        prime=False
        break
print(prime)
# Out:
# False

# %%
# Question 7: Find the factorial of 8
import math
print("factorial:",math.factorial(8))
# Out:
# factorial: 40320

# %%
num=8
factorial=1
for i in range(1,num+1):
    factorial*=i
print(factorial)
# Out:
# 40320

# %%
num=18
factorial=1
for i in range(1,num+1):
    factorial*=i
    print(factorial)
# Out:
# 1
# 2
# 6
# 24
# 120
# 720
# 5040
# 40320
# 362880
# 3628800
# 39916800
# 479001600
# 6227020800
# 87178291200
# 1307674368000
# 20922789888000
# 355687428096000
# 6402373705728000

# %%
# Question 8: Calculate the average of numbers: 15, 23, 31, 42, 56
nums= 15, 23, 31, 42, 56
total=sum(nums)
avg=int(total/len(nums))
print(avg)
# Out:
# 33

# %%
nums=98,87,76,65,54,43,32,21
total=sum(nums)
avg=int(total/len(nums))
print(avg)
# Out:
# 59

# %%
# Question 9: Find the greatest common divisor (GCD) of 48 and 36
a=48
b=36
while b !=0:
    a,b=b,a%b
    print("GCD",a)
# Out:
# GCD 36
# GCD 12

# %%
a=96
b=48
while b !=0:
    a,b=b,a%b
print("GCD",a)
# Out:
# GCD 48

# %%
a=6
b=12
while b !=0:
    a,b=b,a%b
print('GCD',a)
# Out:
# GCD 6

# %%
a=55
b=99
while b !=0:
    a,b=b,a%b
print(a)
# Out:
# 11

# %%
# Question 10: Calculate the sum of first 20 odd numbers

sum_odd=0
for i in range(1,41):
    if i % 2 !=0:
        sum_odd+=(i)
print((sum_odd))
# Out:
# 400

# %%
odd=[i for i in range(1,40,2)]
print(sum(odd))
type(odd)
# Out:
# 400
# list

# %%
sum_odd=0
for i in range(1,41):
    if i%2!=0:
        sum_odd+=int(i)
print(sum_odd)
type(sum_odd)
# Out:
# 400
# int

# %%
odd=0
for i in range(1,40,2):
    odd += i
print(odd)
type(odd)
# Out:
# 400
# int

# %%
odd=0
for i in range(1,41):
    if i % 2 !=0:
        odd+=i
print(odd)
# Out:
# 400

# %%
odd=[]
for i in range(1,40,2):
    odd.append(i)
print(sum(odd))
# Out:
# 400

# %%
result=[i for i in range(1,40,2)]
print(sum(result))
# Out:
# 400

# %%
odd=[]
for i in range(1,40,2):
    odd.append(i)
print(sum(odd))
# Out:
# 400
